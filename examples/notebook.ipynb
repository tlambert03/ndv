# %%
# /// script
# requires-python = ">=3.10"
# dependencies = [
#     "imageio[tifffile]",
#     "ndv[jupyter,vispy]",
# ]
#
# [tool.uv.sources]
# ndv = { path = "../" }
# ///

# %%
from ndv import data, imshow

viewer = imshow(data.cells3d())
viewer.display_model.channel_mode = "composite"
viewer.display_model.current_index.update({0: 32})
# Out:
# RFBOutputContext()
# VBox(children=(BoundedFloatText(value=0.0, description='Ignore Lower Tail:', step=0.1, style=DescriptionStyle(…
# VBox(children=(HBox(children=(Label(value='.ndarray (60, 2, 256, 256), uint16, 15MB'), Image(value=b'GIF89a\x1…
# VBox(children=(BoundedFloatText(value=0.0, description='Ignore Lower Tail:', step=0.1, style=DescriptionStyle(…
# VBox(children=(BoundedFloatText(value=0.0, description='Ignore Lower Tail:', step=0.1, style=DescriptionStyle(…

# %%
viewer.display_model.visible_axes = (0, 3)

# %%
viewer.display_model.default_lut.cmap = "magma"
viewer.display_model.channel_mode = "grayscale"
