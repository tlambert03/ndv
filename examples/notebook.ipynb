# %%
# /// script
# requires-python = ">=3.10"
# dependencies = [
#     "imageio[tifffile]",
#     "ndv[jupyter,vispy]",
# ]
#
# [tool.uv.sources]
# ndv = { path = "../" }
# ///

# %%
from ndv import data, imshow

viewer = imshow(data.cells3d())
viewer.display_model.channel_mode = "composite"
viewer.display_model.current_index.update({0: 32})
# Out:
# RFBOutputContext()
# NdvWidgetState(sliders=[{'axis': '0', 'label': '0', 'min': 0, 'max': 59, 'value': 0, 'step': 1, 'visible': True}, {'axis': '1', 'label': '1', 'min': 0, 'max': 1, 'value': 0, 'step': 1, 'visible': True}, {'axis': '2', 'label': '2', 'min': 0, 'max': 255, 'value': 0, 'step': 1, 'visible': False}, {'axis': '3', 'label': '3', 'min': 0, 'max': 255, 'value': 0, 'step': 1, 'visible': False}], luts=[{'key': 'None', 'name': '', 'visible': True, 'cmap_name': 'gray', 'cmap_colors': [[0, 0, 0, 255], [4, 4, 4, 255], [8, 8, 8, 255], [12, 12, 12, 255], [16, 16, 16, 255], [20, 20, 20, 255], [24, 24, 24, 255], [28, 28, 28, 255], [32, 32, 32, 255], [36, 36, 36, 255], [40, 40, 40, 255], [44, 44, 44, 255], [48, 48, 48, 255], [52, 52, 52, 255], [56, 56, 56, 255], [60, 60, 60, 255], [65, 65, 65, 255], [69, 69, 69, 255], [73, 73, 73, 255], [77, 77, 77, 255], [81, 81, 81, 255], [85, 85, 85, 255], [89, 89, 89, 255], [93, 93, 93, 255], [97, 97, 97, 255], [101, 101, 101, 255], [105, 105, 105, 255], [109, 109, 109, 255], [113, 113, 113, 255], [117, 117, 117, 255], [121, 121, 121, 255], [125, 125, 125, 255], [130, 130, 130, 255], [134, 134, 134, 255], [138, 138, 138, 255], [142, 142, 142, 255], [146, 146, 146, 255], [150, 150, 150, 255], [154, 154, 154, 255], [158, 158, 158, 255], [162, 162, 162, 255], [166, 166, 166, 255], [170, 170, 170, 255], [174, 174, 174, 255], [178, 178, 178, 255], [182, 182, 182, 255], [186, 186, 186, 255], [190, 190, 190, 255], [195, 195, 195, 255], [199, 199, 199, 255], [203, 203, 203, 255], [207, 207, 207, 255], [211, 211, 211, 255], [215, 215, 215, 255], [219, 219, 219, 255], [223, 223, 223, 255], [227, 227, 227, 255], [231, 231, 231, 255], [235, 235, 235, 255], [239, 239, 239, 255], [243, 243, 243, 255], [247, 247, 247, 255], [251, 251, 251, 255], [255, 255, 255, 255]], 'cmap_options': ['gray', 'green', 'magenta', 'cyan', 'red', 'blue', 'yellow'], 'clim_min': 897.0, 'clim_max': 5402.0, 'clim_bound_min': 0.0, 'clim_bound_max': 65535.0, 'auto_clim': True, 'auto_lower_tail': 0, 'auto_upper_tail': 0, 'gamma': 1.0, 'show_histogram_btn': True, 'show_cmap': True, 'row_visible': True}], channel_mode='grayscale', channel_mode_options=[{'value': 'grayscale', 'label': 'grayscale', 'enabled': True}, {'value': 'composite', 'label': 'composite', 'enabled': True}, {'value': 'rgba', 'label': 'rgba', 'enabled': False}], data_info='.ndarray (60, 2, 256, 256), uint16, 15MB', hover_info='', is_3d=False, show_3d_button=True, show_controls=True, show_channel_mode_selector=True, show_reset_zoom_button=True, show_roi_button=False, show_histogram_button=True, use_shared_histogram=True, show_data_info=True, progress_visible=False, shared_histogram_visible=False, shared_histogram_log=False, _canvas_model_id='f75a16652b1d4b4cb405b778534727d9', _shared_histogram_model_id='', _js_event={})

# %%
viewer.display_model.visible_axes = (0, 3)

# %%
viewer.display_model.default_lut.cmap = "magma"
viewer.display_model.channel_mode = "grayscale"

# %%
viewer.show()
# Out:
# NdvWidgetState(sliders=[{'axis': '0', 'label': '0', 'min': 0, 'max': 59, 'value': 32, 'step': 1, 'visible': True}, {'axis': '1', 'label': '1', 'min': 0, 'max': 1, 'value': 0, 'step': 1, 'visible': True}, {'axis': '2', 'label': '2', 'min': 0, 'max': 255, 'value': 0, 'step': 1, 'visible': False}, {'axis': '3', 'label': '3', 'min': 0, 'max': 255, 'value': 0, 'step': 1, 'visible': False}], luts=[{'key': 'None', 'name': '', 'visible': True, 'cmap_name': 'magma', 'cmap_colors': [[0, 0, 3, 255], [1, 1, 9, 255], [3, 3, 17, 255], [6, 5, 25, 255], [10, 7, 34, 255], [14, 10, 42, 255], [18, 13, 51, 255], [23, 15, 60, 255], [28, 16, 70, 255], [34, 17, 80, 255], [40, 17, 89, 255], [47, 16, 98, 255], [53, 15, 106, 255], [60, 15, 113, 255], [67, 15, 117, 255], [74, 16, 121, 255], [82, 18, 124, 255], [88, 21, 126, 255], [94, 23, 127, 255], [101, 26, 128, 255], [107, 28, 128, 255], [113, 31, 129, 255], [119, 33, 129, 255], [126, 36, 129, 255], [132, 38, 129, 255], [138, 40, 129, 255], [145, 42, 128, 255], [151, 44, 127, 255], [158, 46, 126, 255], [164, 48, 125, 255], [171, 51, 124, 255], [177, 53, 122, 255], [185, 55, 120, 255], [192, 58, 117, 255], [198, 60, 115, 255], [205, 63, 112, 255], [211, 66, 109, 255], [217, 70, 106, 255], [222, 74, 103, 255], [228, 78, 100, 255], [232, 84, 97, 255], [237, 89, 95, 255], [240, 96, 93, 255], [243, 103, 91, 255], [246, 110, 91, 255], [248, 117, 92, 255], [249, 125, 93, 255], [251, 132, 96, 255], [252, 142, 99, 255], [253, 149, 103, 255], [253, 157, 107, 255], [253, 164, 112, 255], [254, 172, 117, 255], [254, 179, 123, 255], [254, 187, 128, 255], [254, 194, 134, 255], [254, 201, 141, 255], [253, 209, 147, 255], [253, 216, 154, 255], [253, 223, 161, 255], [252, 230, 168, 255], [252, 238, 176, 255], [252, 245, 183, 255], [251, 252, 191, 255]], 'cmap_options': ["Colormap(name='matlab:gray', <2 colors>)", "Colormap(name='cmap:green', <2 colors>)", "Colormap(name='cmap:magenta', <2 colors>)", "Colormap(name='cmap:cyan', <2 colors>)", "Colormap(name='cmap:red', <2 colors>)", "Colormap(name='cmap:blue', <2 colors>)", "Colormap(name='cmap:yellow', <2 colors>)"], 'clim_min': 190.0, 'clim_max': 59731.0, 'clim_bound_min': 0.0, 'clim_bound_max': 65535.0, 'auto_clim': True, 'auto_lower_tail': 0, 'auto_upper_tail': 0, 'gamma': 1.0, 'show_histogram_btn': True, 'show_cmap': True, 'row_visible': True}, {'key': '0', 'name': '0', 'visible': True, 'cmap_name': 'green', 'cmap_colors': [[0, 0, 0, 255], [0, 4, 0, 255], [0, 8, 0, 255], [0, 12, 0, 255], [0, 16, 0, 255], [0, 20, 0, 255], [0, 24, 0, 255], [0, 28, 0, 255], [0, 32, 0, 255], [0, 36, 0, 255], [0, 40, 0, 255], [0, 44, 0, 255], [0, 48, 0, 255], [0, 52, 0, 255], [0, 56, 0, 255], [0, 60, 0, 255], [0, 65, 0, 255], [0, 69, 0, 255], [0, 73, 0, 255], [0, 77, 0, 255], [0, 81, 0, 255], [0, 85, 0, 255], [0, 89, 0, 255], [0, 93, 0, 255], [0, 97, 0, 255], [0, 101, 0, 255], [0, 105, 0, 255], [0, 109, 0, 255], [0, 113, 0, 255], [0, 117, 0, 255], [0, 121, 0, 255], [0, 125, 0, 255], [0, 130, 0, 255], [0, 134, 0, 255], [0, 138, 0, 255], [0, 142, 0, 255], [0, 146, 0, 255], [0, 150, 0, 255], [0, 154, 0, 255], [0, 158, 0, 255], [0, 162, 0, 255], [0, 166, 0, 255], [0, 170, 0, 255], [0, 174, 0, 255], [0, 178, 0, 255], [0, 182, 0, 255], [0, 186, 0, 255], [0, 190, 0, 255], [0, 195, 0, 255], [0, 199, 0, 255], [0, 203, 0, 255], [0, 207, 0, 255], [0, 211, 0, 255], [0, 215, 0, 255], [0, 219, 0, 255], [0, 223, 0, 255], [0, 227, 0, 255], [0, 231, 0, 255], [0, 235, 0, 255], [0, 239, 0, 255], [0, 243, 0, 255], [0, 247, 0, 255], [0, 251, 0, 255], [0, 255, 0, 255]], 'cmap_options': ["Colormap(name='matlab:gray', <2 colors>)", "Colormap(name='cmap:green', <2 colors>)", "Colormap(name='cmap:magenta', <2 colors>)", "Colormap(name='cmap:cyan', <2 colors>)", "Colormap(name='cmap:red', <2 colors>)", "Colormap(name='cmap:blue', <2 colors>)", "Colormap(name='cmap:yellow', <2 colors>)"], 'clim_min': 190.0, 'clim_max': 59731.0, 'clim_bound_min': 0.0, 'clim_bound_max': 65535.0, 'auto_clim': True, 'auto_lower_tail': ...
